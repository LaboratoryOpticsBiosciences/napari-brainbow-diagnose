# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

from napari_brainbow_diagnose._channel_density import DensityFigure
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import tifffile
import napari

# %%
fname = "../example_data/chroms_data_sample_8bits.tif"
bb = tifffile.imread(fname)

# %%
viewer = napari.Viewer()

# %%
viewer.add_image(bb)
# Out:
# <Image layer 'bb' at 0x7f68344eb430>

# %%
density_figure.mpl_widget.figure

# %%
from matplotlib.widgets import LassoSelector
density_figure = DensityFigure(bb, 100, log_scale=True, cmap="gray")

lasso = LassoSelector(density_figure.density_ax, density_figure.onselect, button=1)
lasso2 = LassoSelector(density_figure.color_wheel_ax, density_figure.onselect, button=1)

viewer.window.add_dock_widget(density_figure.mpl_widget)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import napari
import tifffile

fname = "../example_data/chroms_data_sample_8bits.tif"
bb = tifffile.imread(fname)
viewer = napari.Viewer()
viewer.add_image(bb)
