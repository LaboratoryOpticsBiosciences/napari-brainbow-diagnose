# %%
import numpy as np
from napari_brainbow_diagnose._matplotlib_utils import resume_polar_plot

theta = np.random.rand(10000) * 2 * np.pi
r = np.random.rand(10000)
resume_polar_plot(theta=theta, r=r, n_angles=30, n_radii=30)

# %%
from napari_brainbow_diagnose._matplotlib_utils import resume_ternary
import numpy as np

data = np.random.rand(10000, 3)
data = data / data.sum(axis=1)[:, None]

resume_ternary(data=data)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/clement/miniforge3/envs/napari-brainbow-diagnose/lib/python3.10/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
