# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib

# if scienceplots is installed, use it
try:
    import scienceplots
    import matplotlib.pyplot as plt
    plt.style.use('science') # used for latex text rendering
except ImportError:
    pass

# %% [markdown]
# ## Create data

# %%
import numpy as np
rgb = np.random.rand(10000, 3)

# %% [markdown]
# ## Visualize using Hue / Saturation wheel

# %%
from napari_brainbow_diagnose._matplotlib_utils import resume_polar_plot

# convert to hsv
from matplotlib.colors import rgb_to_hsv
hsv = rgb_to_hsv(rgb)
theta = hsv[:,0] * 2 * np.pi
r = hsv[:,1]

resume_polar_plot(theta=theta, r=r, bins=(30, 30))

# %% [markdown]
# ## Visualize using Maxwell Triangle

# %%
from napari_brainbow_diagnose._matplotlib_utils import resume_ternary
import numpy as np


maxwell_data = rgb / rgb.sum(axis=1)[:, None]
resume_ternary(data=maxwell_data)
# Out:
# /home/clement/miniforge3/envs/napari-brainbow-diagnose/lib/python3.10/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)

# %% [markdown]
# ## Plot the data in all channel spaces

# %%
from napari_brainbow_diagnose._matplotlib_utils import plot_all

plot_all(rgb)
# Out:
# /home/clement/miniforge3/envs/napari-brainbow-diagnose/lib/python3.10/site-packages/ternary/plotting.py:148: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(xs, ys, vmin=vmin, vmax=vmax, **kwargs)
# (<Figure size 2000x4000 with 13 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: xlabel='Hue', ylabel='Saturation'>,
#          <Axes: xlabel='Hue', ylabel='Saturation'>],
#         [<Axes: xlabel='Theta', ylabel='Phi'>,
#          <Axes: xlabel='Theta', ylabel='Phi'>],
#         [<Axes: xlabel='Hue', ylabel='Value'>,
#          <Axes: xlabel='Hue', ylabel='Value'>],
#         [<PolarAxes: xlabel='Hue'>, <PolarAxes: xlabel='Hue'>]],
#        dtype=object))
